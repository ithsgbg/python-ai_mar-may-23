# %%
import pandas as pd

estonia_df = pd.read_csv('estonia.csv')

# %%
estonia_df.shape
# Out:
# (989, 8)

# %%
estonia_df.columns
# Out:
# Index(['PassengerId', 'Country', 'Firstname', 'Lastname', 'Sex', 'Age',
#        'Category', 'Survived'],
#       dtype='object')

# %%
estonia_df.describe()
# Out:
#        PassengerId         Age    Survived
# count   989.000000  989.000000  989.000000
# mean    494.992922   44.575329    0.138524
# std     285.643660   17.235146    0.345624
# min       1.000000    0.000000    0.000000
# 25%     248.000000   30.000000    0.000000
# 50%     495.000000   44.000000    0.000000
# 75%     742.000000   59.000000    0.000000
# max     989.000000   87.000000    1.000000

# %%
estonia_df.head()
# Out:
#    PassengerId  Country        Firstname  Lastname Sex  Age Category  Survived
# 0            1   Sweden      ARVID KALLE     AADLI   M   62        P         0
# 1            2  Estonia              LEA   AALISTE   F   22        C         0
# 2            3  Estonia             AIRI   AAVASTE   F   21        C         0
# 3            4   Sweden             JURI     AAVIK   M   53        C         0
# 4            5   Sweden  BRITTA ELISABET  AHLSTROM   F   55        P         0

# %%
pd.value_counts(estonia_df.Survived)
# Out:
# 0    852
# 1    137
# Name: Survived, dtype: int64

# %%
pd.value_counts(estonia_df.Sex)
# Out:
# M    503
# F    486
# Name: Sex, dtype: int64

# %%
estonia_df.groupby(['Sex'])['Survived'].mean()
# Out:
# Sex
# F    0.055556
# M    0.218688
# Name: Survived, dtype: float64

# %%
pd.value_counts(estonia_df['Age'] < 18)
# Out:
# False    965
# True      24
# Name: Age, dtype: int64

# %%
estonia_df[estonia_df.Age < 18].groupby(['Sex'])['Survived'].mean()
# Out:
# Sex
# F    0.0
# M    0.2
# Name: Survived, dtype: float64

# %%
estonia_df.groupby(['Sex', 'Category'])['Survived'].mean().plot.bar()
# Out:
# <Axes: xlabel='Sex,Category'>

# %%
estonia_df.groupby(['Sex', 'Category'])['Survived'].mean()
# Out:
# Sex  Category
# F    C           0.100917
#      P           0.042440
# M    C           0.333333
#      P           0.195704
# Name: Survived, dtype: float64

# %%
estonia_df.Country.value_counts()
# Out:
# Sweden           550
# Estonia          344
# Latvia            28
# Finland           16
# Russia            14
# Norway             9
# Germany            8
# Denmark            6
# Lithuania          4
# Great Britain      2
# Morocco            2
# Netherlands        2
# France             1
# Nigeria            1
# Canada             1
# Belarus            1
# Name: Country, dtype: int64

# %%
estonia_df[estonia_df.Country.isin(['Sweden', 'Estonia'])].groupby(['Country', 'Survived']).Survived.count()
# Out:
# Country  Survived
# Estonia  0           280
#          1            64
# Sweden   0           501
#          1            49
# Name: Survived, dtype: int64

# %%
estonia_df.groupby(['Sex', 'Country'])['Survived'].mean()
# Out:
# Sex  Country
# F    Belarus          0.000000
#      Canada           0.000000
#      Denmark          0.000000
#      Estonia          0.086957
#      Finland          0.000000
#      France           0.000000
#      Germany          0.000000
#      Latvia           0.100000
#      Lithuania        0.000000
#      Norway           0.000000
#      Russia           0.000000
#      Sweden           0.040134
# M    Denmark          0.200000
#      Estonia          0.273224
#      Finland          0.500000
#      Germany          0.428571
#      Great Britain    0.500000
#      Latvia           0.277778
#      Lithuania        0.500000
#      Morocco          0.000000
#      Netherlands      0.500000
#      Nigeria          0.000000
#      Norway           0.428571
#      Russia           0.181818
#      Sweden           0.147410
# Name: Survived, dtype: float64
